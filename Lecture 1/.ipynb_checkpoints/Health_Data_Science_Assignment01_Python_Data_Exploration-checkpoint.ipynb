# %% [markdown]
# # Health Data Science — Assignment 1
# ## Exploring Health Data with Python
# ### Deadline: September 12, 23:59
#
# ### Main tools
# - NumPy
# - pandas
# - Matplotlib
# - Jupyter Notebook
#
# ### Purpose
#
# The goal of this assignment is to practise the fundamental Python tools that we will use throughout the course.
#
#
# The emphasis is on:
#
# - understanding the data;
# - manipulating data correctly;
# - visualising data clearly;
# - documenting your work;
# - interpreting what you observe.
#
# ### Submission
#
# Submit one Jupyter Notebook named:
#
# ```text
# Assignment01_GroupXX.ipynb
# ```
#
# Your notebook should:
#
# - run from beginning to end without errors;
# - contain all requested Python code;
# - contain all requested plots;
# - include answers in Markdown cells;
# - use meaningful section headings;
# - clearly explain the main findings.

# %% [markdown]
# # Scenario
#
# Imagine that a small wearable study has collected data from several participants.
#
# For each participant, we have:
#
# - participant ID;
# - age;
# - sex;
# - activity type;
# - heart rate;
# - step count;
# - recording duration;
# - signal-quality score.
#
# You are also given a short physiological time series representing a wearable signal.
#
# Your task is to explore these data using Python.

# %% [markdown]
# # Part 1 — NumPy and physiological time-series data
#
# Run the starter code below.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

np.random.seed(42)

fs = 100
duration = 20

time = np.arange(0, duration, 1/fs)

signal = (
    0.8 * np.sin(2 * np.pi * 1.2 * time)
    + 0.25 * np.sin(2 * np.pi * 2.4 * time)
    + 0.15 * np.random.randn(len(time))
)

print("Signal created successfully.")

# %% [markdown]
# ## Task 1.1 — Understand the array
#
# Use Python to determine:
#
# 1. The number of samples in `signal`
# 2. The shape of the array
# 3. The data type
# 4. The minimum signal value
# 5. The maximum signal value
# 6. The mean
# 7. The standard deviation
#
# Present the results clearly.

# %%
# Your solution here

# %% [markdown]
# ## Task 1.2 — Work with time and sampling frequency
#
# Answer the following using Python:
#
# 1. How many samples represent one second?
# 2. How many samples represent five seconds?
# 3. Which array indices correspond to the interval from 5 to 10 seconds?
# 4. Extract this interval into a new variable called `signal_5_10`.
# 5. Check that its length is what you expect.

# %%
# Your solution here

# %% [markdown]
# ## Task 1.3 — Visualise the signal
#
# Create a plot of the entire 20-second recording.
#
# Your plot must contain:
#
# - an informative title;
# - time in seconds on the x-axis;
# - signal amplitude on the y-axis;
# - a grid.
#
# Then create a second plot showing only the interval from 5 to 10 seconds.

# %%
# Plot the complete signal here

# %%
# Plot the 5-10 second interval here

# %% [markdown]
# ### Question
#
# Why can the shorter plot sometimes be more useful than plotting the entire recording?
#
# **Write your answer below in 2–3 sentences.**

# %% [markdown]
# **Answer:**
# _Write your answer here._

# %% [markdown]
# # Part 2 — Working with tabular health data using pandas
#
# Run the code below to create a small wearable-health dataset.

# %%
data = {
    "participant_id": ["P01", "P02", "P03", "P04", "P05",
                       "P06", "P07", "P08", "P09", "P10"],
    "age": [24, 31, 28, 45, 52, 37, 41, 29, 34, 48],
    "sex": ["F", "M", "F", "M", "F", "M", "F", "M", "F", "M"],
    "activity": ["Walking", "Rest", "Running", "Walking", "Rest",
                 "Running", "Walking", "Rest", "Running", "Walking"],
    "heart_rate": [96, 68, 145, 101, 72, 152, 92, 65, 148, 105],
    "steps": [1850, 120, 3240, 2010, 90, 3560, 1760, 150, 3380, 2200],
    "recording_minutes": [28, 30, 25, 30, 29, 24, 30, 27, 26, 30],
    "signal_quality": [0.95, 0.98, 0.82, 0.91, 0.97,
                       0.76, 0.94, 0.96, 0.79, 0.89]
}

df = pd.DataFrame(data)
df

# %% [markdown]
# # Part 3 — Inspect the dataset
#
# Use pandas commands to:
#
# 1. Display the first five rows.
# 2. Determine the number of rows and columns.
# 3. List the column names.
# 4. Display the data types.
# 5. Produce descriptive statistics for the numerical columns.
# 6. Determine whether any values are missing.

# %%
# Your solution here

# %% [markdown]
# ### Question
#
# What does one row represent in this dataset?
#
# **Answer:**
# _Write your answer here._

# %% [markdown]
# # Part 4 — Selecting and filtering data

# %% [markdown]
# ## Task 4.1 — Participants older than 35

# %%
older_participants = ...

# Display the result

# %% [markdown]
# ## Task 4.2 — Participants whose heart rate is greater than 100

# %%
high_hr = ...

# Display the result

# %% [markdown]
# ## Task 4.3 — Participants performing `Running`

# %%
running = ...

# Display the result

# %% [markdown]
# ## Task 4.4 — Participants with signal quality below 0.85

# %%
low_quality = ...

# Display the result

# %% [markdown]
# ### Report
#
# For each subset, report the number of participants.

# %%
# Your solution here

# %% [markdown]
# # Part 5 — Grouping and summarising
#
# Use pandas to calculate:
#
# 1. Mean heart rate for each activity
# 2. Mean number of steps for each activity
# 3. Mean signal quality for each activity

# %%
# Your solution here

# %% [markdown]
# ### Questions
#
# 1. Which activity has the highest average heart rate?
# 2. Which activity has the lowest average heart rate?
# 3. Does the pattern make physiological sense?
# 4. Which activity appears to have the lowest signal quality?
# 5. Can we conclude from only ten participants that the activity itself causes poorer signal quality? Why or why not?

# %% [markdown]
# **Answers:**
#
# 1.
# 2.
# 3.
# 4.
# 5.

# %% [markdown]
# # Part 6 — Data visualisation

# %% [markdown]
# ## Figure 1 — Heart rate by participant
#
# Create a bar chart showing heart rate for all participants.
#
# Requirements:
#
# - participant ID on the x-axis;
# - heart rate on the y-axis;
# - descriptive title;
# - readable labels.

# %%
# Your plot here

# %% [markdown]
# ## Figure 2 — Steps versus heart rate
#
# Create a scatter plot with:
#
# - number of steps on the x-axis;
# - heart rate on the y-axis.

# %%
# Your plot here

# %% [markdown]
# ### Question
#
# What relationship do you observe?
#
# Do not calculate a statistical test yet. Simply describe what you see.
#
# **Answer:**
# _Write your answer here._

# %% [markdown]
# ## Figure 3 — Mean heart rate by activity
#
# Create a visualisation comparing mean heart rate across:
#
# - Rest
# - Walking
# - Running

# %%
# Your plot here

# %% [markdown]
# ### Question
#
# Which figure communicates the effect of activity most clearly: Figure 1, Figure 2, or Figure 3?
#
# Explain your choice.
#
# **Answer:**
# _Write your answer here._

# %% [markdown]
# # Part 7 — Introduce a data-quality problem

# %%
df_missing = df.copy()

df_missing.loc[2, "heart_rate"] = np.nan
df_missing.loc[7, "signal_quality"] = np.nan

df_missing

# %% [markdown]
# Now:
#
# 1. Check the number of missing values in each column.
# 2. Find the rows containing missing values.
# 3. Calculate the mean heart rate using pandas.
# 4. Investigate what pandas does with the missing value when calculating the mean.

# %%
# Your solution here

# %% [markdown]
# ### Question
#
# Why is it important to inspect missing data before performing an analysis?
#
# **Write 2–4 sentences.**

# %% [markdown]
# **Answer:**
# _Write your answer here._

# %% [markdown]
# # Part 8 — Create new variables
#
# Create a new column called `recording_seconds` using:
#
# ```text
# recording_minutes × 60
# ```
#
# Then create another column called `steps_per_minute` using:
#
# ```text
# steps / recording_minutes
# ```

# %%
# Your solution here

# %% [markdown]
# Display only the following columns:
#
# - `participant_id`
# - `activity`
# - `steps`
# - `recording_minutes`
# - `steps_per_minute`

# %%
# Your solution here

# %% [markdown]
# ### Question
#
# Why might `steps_per_minute` sometimes be more informative than total `steps`?
#
# **Answer:**
# _Write your answer here._

# %% [markdown]
# # Part 9 — A small Health Data Science question
#
# Suppose you are interested in:
#
# > **Does physical activity appear to be associated with heart rate in this small dataset?**
#
# Use the tools from this assignment to answer the question.
#
# Your analysis should contain:
#
# 1. one table;
# 2. one figure;
# 3. one numerical summary;
# 4. a short conclusion of approximately 100–150 words.
#
# Your conclusion should distinguish between:
#
# - what the data show;
# - what you think may explain the observation;
# - what cannot be concluded from this small dataset.

# %%
# Create your table / numerical summary here

# %%
# Create your figure here

# %% [markdown]
# ### Conclusion
#
# _Write approximately 100–150 words here._

# %% [markdown]
# # Part 10 — Reflection
#
# Answer the following questions briefly.
#
# 1. What is the difference between a NumPy array and a pandas DataFrame?
# 2. When would you prefer a NumPy array?
# 3. When would you prefer a pandas DataFrame?
# 4. Why is visualising health data important before performing further analysis?
# 5. Why should column names, units, participant IDs and other metadata be preserved?
# 6. What was the most useful Python operation you learned in this assignment?

# %% [markdown]
# ## Reflection answers
#
# 1.
# 2.
# 3.
# 4.
# 5.
# 6.

# %% [markdown]
# # Optional challenge
#
# This section is **not required**.
#
# Create a new variable called `activity_code` using:
#
# - Rest = 0
# - Walking = 1
# - Running = 2
#
# Then create a scatter plot showing:
#
# ```text
# activity_code versus heart_rate
# ```
#
# ### Question
#
# Do you think representing activities numerically in this way is always meaningful?
#
# Explain your answer.

# %%
# Optional challenge

# %% [markdown]
# **Optional challenge answer:**
# _Write your answer here._

# %% [markdown]
# # Submission checklist
#
# Before submitting, check that:
#
# - [ ] The notebook runs from beginning to end without errors.
# - [ ] All requested code is included.
# - [ ] All requested figures are included.
# - [ ] Axes and figures have meaningful labels/titles.
# - [ ] All written questions are answered.
# - [ ] Markdown cells are used for explanations.
# - [ ] No unnecessary outputs remain.
# - [ ] Your notebook has a clear filename.
